# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelCortezPino/etl-data-pipeline-1701472022/blob/main/notebooks/E_bodega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/MiguelCortezPino/etl-data-pipeline-1701472022/refs/heads/main/data/raw/E_bodegas.csv"

df = pd.read_csv(url)

df.head()
# Out:
#   id_bodega       bodega   ubicacion capacidad_m2
# 0    BOD100   Central 0     Usulután      1292 m2
# 1    BOD101        Sur 1  San Miguel         2047
# 2    BOD102    Central 2   Sonsonate       651 m2
# 3    BOD103  Occidente 3  San Miguel         2250
# 4    BOD104        Sur 4   Santa Ana          239

# %%
#Exploracion de datos
df.shape
df.columns
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_bodega     18 non-null     object
#  1   bodega        20 non-null     object
#  2   ubicacion     20 non-null     object
#  3   capacidad_m2  20 non-null     object
# dtypes: object(4)
# memory usage: 772.0+ bytes
# id_bodega       2
# bodega          0
# ubicacion       0
# capacidad_m2    0
# dtype: int64

# %%
#Limpieza de datos
E_bodegas = df.copy()
print(E_bodegas['id_bodega'].value_counts(dropna=False))
# Out:
# id_bodega
# BOD103    2
# NaN       2
# BOD106    2
# BOD100    1
# BOD102    1
# BOD104    1
# BOD105    1
# BOD107    1
# BOD101    1
# BOD108    1
# BOD109    1
# BOD111    1
# BOD112    1
# BOD113    1
# BOD115    1
# BOD116    1
# BOD117    1
# Name: count, dtype: int64

# %%
E_bodegas['capacidad_m2'].value_counts(dropna=False)
# Out:
# capacidad_m2
# 1783       2
# 2250       2
# 2047       1
# 1292 m2    1
# 239        1
# 651 m2     1
# 1546       1
# 2181       1
# 1359       1
# 2097       1
# 299        1
# 1582       1
# 413 m2     1
# 1062       1
# 1635       1
# 2217       1
# 788        1
# 1904       1
# Name: count, dtype: int64

# %%
#Quitar m2 de capacidad_m2
E_bodegas = df.copy()
E_bodegas['capacidad_m2'] = E_bodegas['capacidad_m2'].str.replace('m2', '')
print(E_bodegas['capacidad_m2'].value_counts(dropna=False))
# Out:
# capacidad_m2
# 1783     2
# 2250     2
# 2047     1
# 1292     1
# 239      1
# 651      1
# 1546     1
# 2181     1
# 1359     1
# 2097     1
# 299      1
# 1582     1
# 413      1
# 1062     1
# 1635     1
# 2217     1
# 788      1
# 1904     1
# Name: count, dtype: int64

# %%
#Separar válidos y rechazados

validos = E_bodegas[
    E_bodegas['id_bodega'].notna() &
    E_bodegas['bodega'].notna() &
    E_bodegas['ubicacion'].notna() &
    E_bodegas['capacidad_m2'].notna()
].copy()
rechazados = E_bodegas[
    E_bodegas['id_bodega'].isna() |
    E_bodegas['bodega'].isna() |
    E_bodegas['ubicacion'].isna() |
    E_bodegas['capacidad_m2'].isna()
].copy()

# %%
#Motivo de rechazo

def motivo(row):

    motivos = []

    if pd.isna(row['id_bodega']):
        motivos.append("id_bodega_vacio")

    return ",".join(motivos)

rechazados["motivo_rechazo"] = rechazados.apply(motivo, axis=1)

# %%
validos.to_csv("E_bodegas_curated.csv", index=False)

rechazados.to_csv("E_bodegas_rejects.csv", index=False)
